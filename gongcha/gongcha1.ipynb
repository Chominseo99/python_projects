# %% [markdown]
# <a href="https://colab.research.google.com/github/Chominseo99/python_projects/blob/main/gongcha1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 포스기, 키오스크 만들기
# 메뉴, 음료 선택, 사이즈, 타입(아이스, 핫), 토핑, 당도, 얼음양

# price_bestcombination = {''}

import datetime

menu = ['베스트콤비네이션', '오리지널 티', '밀크티', '브라운 슈가', '과일믹스', '스무디', '커피']

best_combination = ['블랙밀크티+펄', '타로밀크티+펄', '망고요구르트+화이트펄', '제주그린밀크티+펄', '패션후르츠히비스커스+코코넛', '우롱티+밀크폼']
best_combination_price = [4200, 4200, 5200, 4900, 4500, 3700]

original_tea = ['자스민그린티', '우롱티', '블랙티', '얼그레이티']
original_tea_price = [3500, 3500, 3500, 3500]

milk_tea = ['민트초코칩밀크티+펄', '복숭아쥬얼리밀크티', '피스타치오밀크티+펄', '망고치즈폼밀크티', '딸기쥬얼리밀크티', '자스민그린밀크티', '우롱밀크티', '블랙밀크티', '얼그레이밀크티', '타로밀크티', '초콜렛밀크티', '제주그린밀크티', '딸기쏙쏙쥬얼리밀크티', '딸기쿠키밀크티']
milk_tea_price = [4900, 5100, 4900, 4900, 5100, 4000, 4000, 4000, 4000, 4000, 4000, 4700, 5100, 4900]

brown_sugar = ['브라운슈가치즈폼쿠키밀크티', '브라운슈가커피밀크티', '브라운슈가쥬얼리밀크티', '브라운슈가치즈폼스무디']
brown_sugar_price = [5700, 5700, 5300, 5700]

fruit_mix = ['망고쥬스', '망고요구르트', '자몽그린티', '청포도그린티', '패션후르츠히비스커스', '자몽주스']
fruit_mix_price = [4600, 5000, 4300, 4300, 4300, 4600]

smoothie = ['민트팝핑초코스무디', '초코바른민트쿠키스무디', '복숭아쥬얼리요구르트크러쉬', '초코바른피스타치오스무디', '망고요구르트쥬얼리크러쉬', '돌체크러쉬위드샷L', '초코바른제주그린스무디', '초코바른초코스무디', '딸기&요구르트크러쉬', '치즈폼딥초코스무디', '망고스무디L', '초코쿠앤크스무디L', '청포도스무디L', '제주그린티스무디L', '체리바른딸기크러쉬', '딸기치즈쿠키크러쉬', '딸기쿠키스무디']
smoothie_price = [5300, 5300, 5300, 5300, 5300, 5300, 5700, 5500, 5300, 5300, 5300, 4500, 4800, 5300, 5500, 5500, 5300]

coffee = ['돌체카페라떼', '카라멜카페라떼', '바닐라카페라떼', '모카카페라떼', '아메리카노', '카페라떼']
coffee_price = [4700, 4500, 4500, 4500, 3500, 4000]

size = []
size_price = []

type = []
type_price = []

topping = []
topping_price = []

sugar = []
sugar_price = []

ice = []
ice_price = []

order = []
total = 0
# current_pay = 0
# global

def plus_best_combination(choice):
    global total
    order.append(best_combination[choice-1])
    total += best_combination_price[choice-1]
    print(total)

def plus_original_tea(choice):
    global total
    order.append(original_tea[choice-1])
    total += original_tea_price[choice-1]
    print(total)

def plus_milk_tea(choice):
    global total
    order.append(milk_tea[choice-1])
    total += milk_tea_price[choice-1]
    print(total)

def plus_brown_sugar(choice):
    global total
    order.append(brown_sugar[choice-1])
    total += brown_sugar_price[choice-1]
    print(total)

def plus_fruit_mix(choice):
    global total
    order.append(fruit_mix[choice-1])
    total += fruit_mix_price[choice-1]
    print(total)

def plus_smoothie(choice):
    global total
    order.append(smoothie[choice-1])
    total += smoothie_price[choice-1]
    print(total)

def plus_coffee(choice):
    global total
    order.append(coffee[choice-1])
    total += coffee_price[choice-1]
    print(total)

def pay(current_pay):
    # global total
    # current_pay = 0
    while True:
        pay_input = int(input('넣을 금액을 입력하세요: '))
        current_pay += pay_input   

        if current_pay < total:
            print('현재 현금 ', current_pay, '원')
            print('금액이 부족합니다. 더 넣어주세요.')
        elif current_pay >= total:
            # current_pay += pay_input
            print('잔돈 ', current_pay - total, '원')
            break

    now = datetime.datetime.now()
    nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S') 

    receipt_paper = '''
        공차 성수점
        대표: 조민서
        주소: 서울시 떡잎구 초록동
        전번: 0102-22933-1

        오늘도 공차를 찾아주셔서 감사합니다.
        '''
    print(receipt_paper)
    # for i in range():
    print('------------------------------------')
    # print('No. 메뉴     단가     수량      금액')
    print(order, sep='\n')
    print('------------------------------------')
    print('합계 ', total, '원')
    print('현금 ', current_pay, '원')
    print('잔돈 ', current_pay - total, '원')
    print('판매일 ', nowDatetime)


def main():
    global total
    while True:
        print('환영합니다. 공차입니다.\n메뉴를 골라주세요.\n')
        for main in range(1, len(menu)):
            print(main, '.' , menu[main])

        choice = int(input('숫자를 입력하세요: '))
        # for i in range(len(best_combination)):
        #     print(best_combination[i], '-', best_combination_price[i])
        if choice == 1:
            # a = 0
            # while True: 

            #     a <= len(best_combination)
            #     print(a, '.', best_combination[a], '-', best_combination_price[a])
            #     a + 1
            # print(a + 1, '.', '뒤로가기')
            for a in range(1, len(best_combination)):
                print(a, '.', best_combination[a], '-', best_combination_price[a])
            print('7 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice <= len(best_combination):
                    plus_best_combination(choice) 
                elif choice == len(best_combination)+1 :
                    print(main)
                    break

                # if choice == 1:
                #     plus_best_combination(choice)                
                #     continue
                # elif choice == 2:
                #     plus_best_combination(choice) 
                #     continue
                # elif choice == 3:
                #     plus_best_combination(choice) 
                #     continue
                # elif choice == 4:
                #     plus_best_combination(choice) 
                #     continue
                # elif choice == 5:
                #     plus_best_combination(choice) 
                #     continue
                # elif choice == 6:
                #     plus_best_combination(choice) 
                #     continue                
                # elif choice == 7:
                #     print(main)
                #     break

        # for i in range(len(original_tea)):
        #     print(original_tea[i], '-', original_tea_price[i])
        elif choice == 2:
            for b in range(1, len(original_tea)):
                print(b, '.', original_tea[b], '-', original_tea_price[b])
            print('5 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_original_tea(choice)
                    continue
                elif choice == 2:
                    plus_original_tea(choice)
                    continue      
                elif choice == 3:
                    plus_original_tea(choice)
                    continue 
                elif choice == 4:
                    plus_original_tea(choice)
                    continue    
                elif choice == 5:
                    print(main)  
                    break

        elif choice == 3:                
            for c in range(1, len(milk_tea)):
                print(c, '.', milk_tea[c], '-', milk_tea_price[c])
            print('15 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_milk_tea(choice)
                    continue
                elif choice == 2:
                    plus_milk_tea(choice)
                    continue      
                elif choice == 3:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 4:
                    plus_milk_tea(choice)
                    continue  
                elif choice == 5:
                    plus_milk_tea(choice)
                    continue      
                elif choice == 6:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 7:
                    plus_milk_tea(choice)
                    continue
                elif choice == 8:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 9:
                    plus_milk_tea(choice)
                    continue  
                elif choice == 10:
                    plus_milk_tea(choice)
                    continue      
                elif choice == 11:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 12:
                    plus_milk_tea(choice)
                    continue       
                elif choice == 13:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 14:
                    plus_milk_tea(choice)
                    continue
                elif choice == 15:
                    print(main)  
                    break

        elif choice == 4:                
            for d in range(1, len(brown_sugar)):
                print(d, '.', brown_sugar[d], '-', brown_sugar_price[d])
            print('5 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_brown_sugar(choice)
                    continue
                elif choice == 2:
                    plus_brown_sugar(choice)
                    continue      
                elif choice == 3:
                    plus_brown_sugar(choice)
                    continue 
                elif choice == 4:
                    plus_brown_sugar(choice)
                    continue  
                elif choice == 5:
                    print(main)  
                    break

        elif choice == 5:
            for e in range(1, len(fruit_mix)):
                print(e, '.', fruit_mix[e], '-', fruit_mix_price[e])
            print('7 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_fruit_mix(choice)
                    continue
                elif choice == 2:
                    plus_fruit_mix(choice)
                    continue
                elif choice == 3:
                    plus_fruit_mix(choice)
                    continue
                elif choice == 4:
                    plus_fruit_mix(choice)
                    continue
                elif choice == 5:
                    plus_fruit_mix(choice)
                    continue
                elif choice == 6:
                    plus_fruit_mix(choice)
                    continue                
                elif choice == 7:
                    print(main)
                    break

        elif choice == 6:                
            for f in range(1, len(smoothie)):
                print(f, '.', smoothie[f], '-', smoothie_price[f])
            print('18 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_smoothie(choice)
                    continue
                elif choice == 2:
                    plus_smoothie(choice)
                    continue      
                elif choice == 3:
                    plus_smoothie(choice)
                    continue 
                elif choice == 4:
                    plus_smoothie(choice)
                    continue  
                elif choice == 5:
                    plus_smoothie(choice)
                    continue      
                elif choice == 6:
                    plus_smoothie(choice)
                    continue 
                elif choice == 7:
                    plus_smoothie(choice)
                    continue
                elif choice == 8:
                    plus_smoothie(choice)
                    continue 
                elif choice == 9:
                    plus_smoothie(choice)
                    continue  
                elif choice == 10:
                    plus_smoothie(choice)
                    continue      
                elif choice == 11:
                    plus_smoothie(choice)
                    continue 
                elif choice == 12:
                    plus_smoothie(choice)
                    continue       
                elif choice == 13:
                    plus_smoothie(choice)
                    continue 
                elif choice == 14:
                    plus_smoothie(choice)
                    continue
                elif choice == 15:
                    plus_smoothie(choice)
                    continue
                elif choice == 16:
                    plus_smoothie(choice)
                    continue
                elif choice == 17:
                    plus_smoothie(choice)
                    continue
                elif choice == 18:
                    print(main)  
                    break

        elif choice == 7:
            for f in range(1, len(coffee)):
                print(f, '.', coffee[f], '-', coffee_price[f])
            print('7 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_coffee(choice)
                    continue
                elif choice == 2:
                    plus_coffee(choice)
                    continue
                elif choice == 3:
                    plus_coffee(choice)
                    continue
                elif choice == 4:
                    plus_coffee(choice)
                    continue
                elif choice == 5:
                    plus_coffee(choice)
                    continue
                elif choice == 6:
                    plus_coffee(choice)
                    continue                
                elif choice == 7:
                    print(main)
                    break
        # else:
        #     break
            else:
                break
        else:
            break


        print(order)
        print('총 ', total, '원입니다.')


    current_pay = 0
    # current_money = pay(current_pay)
    # receipt(current_money)

    pay(current_pay)



if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f9ee3d7e8115> in <module>()
#     415
#     416 if __name__ == '__main__':
# --> 417     main()
#
# <ipython-input-1-f9ee3d7e8115> in main()
#     136             print(main, '.' , menu[main])
#     137
# --> 138         choice = int(input('숫자를 입력하세요: '))
#     139         # for i in range(len(best_combination)):
#     140         #     print(best_combination[i], '-', best_combination_price[i])
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
