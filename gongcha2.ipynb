# %% [markdown]
# <a href="https://colab.research.google.com/github/Chominseo99/python_projects/blob/main/gongcha2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 포스기, 키오스크 만들기
# 메뉴, 음료 선택, 사이즈, 타입(아이스, 핫), 토핑, 당도, 얼음양

# price_bestcombination = {''}

import datetime

menu = ['베스트콤비네이션', '오리지널 티', '밀크티', '브라운 슈가', '과일믹스', '스무디', '커피']

# best_combination = [{'drink':'블랙밀크티+펄', 'price':4200, }]
best_combination = ['블랙밀크티+펄', '타로밀크티+펄', '망고요구르트+화이트펄', '제주그린밀크티+펄', '패션후르츠히비스커스+코코넛', '우롱티+밀크폼']
best_combination_price = [4200, 4200, 5200, 4900, 4500, 3700]
best_combination_size_price = [0, 1200]
# 다 1200

# original_tea = [{'drink':'자스민그린티', 'drink_price':3500, 'large':0, }]
original_tea = ['자스민그린티', '우롱티', '블랙티', '얼그레이티']
original_tea_price = [3500, 3500, 3500, 3500]
original_tea_size_price = [0, 1100]
# 다 1100

milk_tea = ['민트초코칩밀크티+펄', '복숭아쥬얼리밀크티', '피스타치오밀크티+펄', '망고치즈폼밀크티', '딸기쥬얼리밀크티', '자스민그린밀크티', '우롱밀크티', '블랙밀크티', '얼그레이밀크티', '타로밀크티', '초콜렛밀크티', '제주그린밀크티', '딸기쏙쏙쥬얼리밀크티', '딸기쿠키밀크티']
milk_tea_price = [4900, 5100, 4900, 4900, 5100, 4000, 4000, 4000, 4000, 4000, 4000, 4700, 5100, 4900]
milk_tea_size_price = [0, 1100]
# '자스민그린밀크티', '우롱밀크티', '블랙밀크티', '얼그레이밀크티', '타로밀크티', '초콜렛밀크티', '제주그린밀크티' 만 1100

brown_sugar = ['브라운슈가치즈폼쿠키밀크티', '브라운슈가커피밀크티', '브라운슈가쥬얼리밀크티', '브라운슈가치즈폼스무디']
brown_sugar_price = [5700, 5700, 5300, 5700]
# 점보 없음

fruit_mix = ['망고쥬스', '망고요구르트', '자몽그린티', '청포도그린티', '패션후르츠히비스커스', '자몽주스']
fruit_mix_price = [4600, 5000, 4300, 4300, 4300, 4600]
fruit_mix_size_price = [0, 1100]
# 다 1100

smoothie = ['민트팝핑초코스무디', '초코바른민트쿠키스무디', '복숭아쥬얼리요구르트크러쉬', '초코바른피스타치오스무디', '망고요구르트쥬얼리크러쉬', '돌체크러쉬위드샷L', '초코바른제주그린스무디', '초코바른초코스무디', '딸기&요구르트크러쉬', '치즈폼딥초코스무디', '망고스무디L', '초코쿠앤크스무디L', '청포도스무디L', '제주그린티스무디L', '체리바른딸기크러쉬', '딸기치즈쿠키크러쉬', '딸기쿠키스무디']
smoothie_price = [5300, 5300, 5300, 5300, 5300, 5300, 5700, 5500, 5300, 5300, 5300, 4500, 4800, 5300, 5500, 5500, 5300]
# 점보 없음

coffee = ['돌체카페라떼', '카라멜카페라떼', '바닐라카페라떼', '모카카페라떼', '아메리카노', '카페라떼']
coffee_price = [4700, 4500, 4500, 4500, 3500, 4000]
coffee_size_price = [0, 1100]
americano_size_price = [0, 500]
# 아메리카노 빼고 1100(아메리카노만 500)


size = ['라지', '점보']

type = [{'ICE':0, 'HOT':0}]
# type = ['ICE', 'HOT']
# type_price = [0, 0]

topping = [{'밀크폼':500, '펄':500, '코코넛':500, '알로에':500, '화이트펄':500}]
# topping = ['밀크폼', '펄', '코코넛', '알로에', '화이트펄']
# topping_price = [500, 500, 500, 500, 500]

sugar = [{'0%':0, '30%':0, '50%':0, '70%':0, '100%':0}]
# sugar = ['0%', '30%', '50%', '70%', '100%']
# sugar_price = [0, 0, 0, 0, 0]

no_choice_sugar = [{'당도고정':0}]
# no_choice_sugar = ['당도고정']
# no_choice_sugar_price = [0]

ice = [{'Less':0, 'Regular':0, 'Full':0}]
# ice = ['Less', 'Regular', 'Full']
# ice_price = [0, 0, 0]

no_choice_ice = [{'얼음양 고정':0}]
# no_choice_ice = ['얼음양 고정']
# no_choice_ice_price = [0]


order = []
total = 0
current_pay = 0


def plus_best_combination(menu_choice):
    global total
    order.append(best_combination[menu_choice-1])
    total += best_combination_price[menu_choice-1]
    print(total)

def plus_original_tea(menu_choice):
    global total
    order.append(original_tea[menu_choice-1])
    total += original_tea_price[menu_choice-1]
    print(total)

def plus_milk_tea(menu_choice):
    global total
    order.append(milk_tea[menu_choice-1])
    total += milk_tea_price[menu_choice-1]
    print(total)

def plus_brown_sugar(menu_choice):
    global total
    order.append(brown_sugar[menu_choice-1])
    total += brown_sugar_price[menu_choice-1]
    print(total)

def plus_fruit_mix(menu_choice):
    global total
    order.append(fruit_mix[menu_choice-1])
    total += fruit_mix_price[menu_choice-1]
    print(total)

def plus_smoothie(menu_choice):
    global total
    order.append(smoothie[menu_choice-1])
    total += smoothie_price[menu_choice-1]
    print(total)

def plus_coffee(menu_choice):
    global total
    order.append(coffee[menu_choice-1])
    total += coffee_price[menu_choice-1]
    print(total)


def size_best_combination(choice):
    global total
    order.append(size[choice-1])
    total += best_combination_size_price[choice-1]
    print(total)

def size_original_tea(choice):
    global total
    order.append(size[choice-1])
    total += original_tea_size_price[choice-1]
    print(total)   

def size_fruit_mix(choice):
    global total
    order.append(size[choice-1])
    total += fruit_mix_size_price[choice-1]
    print(total)  

def size_coffee(choice):
    global total
    order.append(size[choice-1])
    total += coffee_size_price[choice-1]
    print(total)  

def size_americano(choice):
    global total
    order.append(size[choice-1])
    total += americano_size_price[choice-1]
    print(total)  


def pay(pay_input):
    global current_pay

    while True:
        pay_input = int(input('넣을 금액을 입력하세요: '))
        current_pay += pay_input 

        if current_pay < total:
            print('현재 현금 ', current_pay, '원')
            print('금액이 부족합니다. 더 넣어주세요.')
        elif current_pay >= total:
            print('잔돈 ', current_pay - total, '원')
            break
    
# def all_order(*order):
#     for total_all_order in order:
#          print("%s %s" % total_all_order[0], total_all_order[1], end='')
#     print("\n")

def receipt(current_pay):
    # global current_pay
    while True:

        now = datetime.datetime.now()
        nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S') 

        receipt_paper = '''
            공차 성수점
            대표: 조민서
            주소: 서울시 떡잎구 초록동
            전번: 0102-22933-1

            오늘도 공차를 찾아주셔서 감사합니다.
            '''
        print(receipt_paper)
        # for i in range():
        print('------------------------------------')
        print('No. 메뉴     단가     수량      금액')
        # for all_order in range(order):
        #     print("%s   %s" % all_order[0], all_order[1], end='')
        # print(sep='\n')
        print(*order, sep='\n')       
        print('------------------------------------')
        print('합계 ', total, '원')
        print('현금 ', current_pay, '원')
        print('잔돈 ', current_pay - total, '원')
        print('판매일 ', nowDatetime)
        break

def first_display(menu):
    print('환영합니다. 공차입니다.\n메뉴를 골라주세요.\n')
    for main in range(len(menu)):
        print(main + 1, '.' , menu[main])

def choice_drink(menu):
    global total
    while True:
        print('환영합니다. 공차입니다.\n메뉴를 골라주세요.\n')
        for main in range(len(menu)):
            print(main + 1, '.' , menu[main])

        menu_choice = int(input('메뉴 -> 숫자를 입력하세요: '))
        if menu_choice == 1:   # 베스트콤비네이션
            for a in range(len(best_combination)):
                print(a + 1, '.', best_combination[a], '-', best_combination_price[a])
            print('7 . 뒤로가기')
            while True:
                best_combination_choice = int(input('베스트콤비네이션 -> 숫자를 입력하세요: '))
                if best_combination_choice == 1:   # 블랙밀크티+펄
                  # plus_best_combination(choice)
                    # order.append(best_combination[choice-1])
                    # total += best_combination_price[choice-1]
                    for aa in range(len(size)):
                        print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
                    print('3 . 뒤로가기')
                    while True:
                        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if size_choice == 1:   # 사이즈
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 2:
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 3:
                            # first_display(menu)
                            # print(main)
                            # continue
                            break   # !!!
                        break   # ...? 이건 의미 없? 
                    continue

                elif best_combination_choice == 2:   # 타로밀크티+펄
                    for aa in range(len(size)):
                        print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
                    print('3 . 뒤로가기')    
                    while True:
                        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if size_choice == 1:   # 사이즈
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 2:
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 3:
                            break
                        break
                    continue

                elif best_combination_choice == 3:   # 망고요구르트+화이트펄
                    print(best_combination[best_combination_choice-1])
                    # plus_best_combination(choice) 
                    for aa in range(len(size)):
                        print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
                    print('3 . 뒤로가기')    
                    while True:
                        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if size_choice == 1:   # 사이즈
                            order.append(best_combination[best_combination_choice-1])
                            print(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 2:
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 3:
                            break
                    continue

                elif best_combination_choice == 4:   # 제주그린밀크티+펄
                    # plus_best_combination(choice) 
                    for aa in range(len(size)):
                        print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
                    print('3 . 뒤로가기')    
                    while True:
                        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if size_choice == 1:   # 사이즈
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 2:
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 3:
                            break
                    continue

                elif best_combination_choice == 5:   # 패션후르츠히비스커스+코코넛
                    # plus_best_combination(choice) 
                    for aa in range(len(size)):
                        print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
                    print('3 . 뒤로가기')    
                    while True:
                        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if size_choice == 1:   # 사이즈
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 2:
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 3:
                            break
                    continue

                elif best_combination_choice == 6:   # 우롱티+밀크폼
                    # plus_best_combination(choice) 
                    for aa in range(len(size)):
                        print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
                    print('3 . 뒤로가기')    
                    while True:
                        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if size_choice == 1:   # 사이즈
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 2:
                            order.append(best_combination[best_combination_choice-1])
                            total += best_combination_price[best_combination_choice-1]
                            size_best_combination(size_choice)
                            break
                        elif size_choice == 3:
                            break
                    continue

                elif best_combination_choice == 7:
                    break

        elif menu_choice == 2:   # 오리지널티
            for b in range(len(original_tea)):
                print(b + 1, '.', original_tea[b], '-', original_tea_price[b])
            print('5 . 뒤로가기')
            while True:
                choice = int(input('오리지널 티 -> 숫자를 입력하세요: '))
                if choice == 1:   # 자스민그린티
                    for bb in range(len(size)):
                        print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 2:
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 2:   # 우롱티
                    for bb in range(len(size)):
                        print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 2:
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue      

                elif choice == 3:   # 블랙티
                    for bb in range(len(size)):
                        print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 2:
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 4:   # 얼그레이티
                    for bb in range(len(size)):
                        print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 2:
                            order.append(original_tea[choice-1])
                            total += original_tea_price[choice-1]  
                            size_original_tea(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 5:
                    break


        elif menu_choice == 3:   # 밀크티          
            for c in range(len(milk_tea)):
                print(c + 1, '.', milk_tea[c], '-', milk_tea_price[c])
            print('15 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_milk_tea(choice)
                    continue
                elif choice == 2:
                    plus_milk_tea(choice)
                    continue      
                elif choice == 3:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 4:
                    plus_milk_tea(choice)
                    continue  
                elif choice == 5:
                    plus_milk_tea(choice)
                    continue      
                elif choice == 6:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 7:
                    plus_milk_tea(choice)
                    continue
                elif choice == 8:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 9:
                    plus_milk_tea(choice)
                    continue  
                elif choice == 10:
                    plus_milk_tea(choice)
                    continue      
                elif choice == 11:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 12:
                    plus_milk_tea(choice)
                    continue       
                elif choice == 13:
                    plus_milk_tea(choice)
                    continue 
                elif choice == 14:
                    plus_milk_tea(choice)
                    continue
                elif choice == 15: 
                    break

        elif menu_choice == 4:                
            for d in range(len(brown_sugar)):
                print(d + 1, '.', brown_sugar[d], '-', brown_sugar_price[d])
            print('5 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_brown_sugar(choice)
                    continue
                elif choice == 2:
                    plus_brown_sugar(choice)
                    continue      
                elif choice == 3:
                    plus_brown_sugar(choice)
                    continue 
                elif choice == 4:
                    plus_brown_sugar(choice)
                    continue  
                elif choice == 5:
                    break

        elif menu_choice == 5:   # 과일믹스
            for e in range(len(fruit_mix)):
                print(e + 1, '.', fruit_mix[e], '-', fruit_mix_price[e])
            print('7 . 뒤로가기')
            while True:
                choice = int(input('과일믹스 -> 숫자를 입력하세요: '))
                if choice == 1:   # 망고쥬스
                    # plus_fruit_mix(choice)
                    for ee in range(len(size)):
                        print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
                    print('3 . 뒤로가기')
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 2:
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 2:   # 망고요구르트
                    for ee in range(len(size)):
                        print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
                    print('3 . 뒤로가기')
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 2:
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 3:   # 자몽그린티
                    for ee in range(len(size)):
                        print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
                    print('3 . 뒤로가기')
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 2:
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 4:   # 청포도그린티
                    for ee in range(len(size)):
                        print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
                    print('3 . 뒤로가기')
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 2:
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 5:   # 패션후르츠히비스커스
                    for ee in range(len(size)):
                        print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
                    print('3 . 뒤로가기')
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 2:
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 6:   # 자몽주스
                    for ee in range(len(size)):
                        print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
                    print('3 . 뒤로가기')
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 2:
                            order.append(fruit_mix[choice-1])
                            total += fruit_mix_price[choice-1]
                            size_fruit_mix(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue       

                elif choice == 7:
                    break

        elif menu_choice == 6:   # 스무디            
            for f in range(len(smoothie)):
                print(f + 1, '.', smoothie[f], '-', smoothie_price[f])
            print('18 . 뒤로가기')
            while True:
                choice = int(input('숫자를 입력하세요: '))
                if choice == 1:
                    plus_smoothie(choice)
                    continue
                elif choice == 2:
                    plus_smoothie(choice)
                    continue      
                elif choice == 3:
                    plus_smoothie(choice)
                    continue 
                elif choice == 4:
                    plus_smoothie(choice)
                    continue  
                elif choice == 5:
                    plus_smoothie(choice)
                    continue      
                elif choice == 6:
                    plus_smoothie(choice)
                    continue 
                elif choice == 7:
                    plus_smoothie(choice)
                    continue
                elif choice == 8:
                    plus_smoothie(choice)
                    continue 
                elif choice == 9:
                    plus_smoothie(choice)
                    continue  
                elif choice == 10:
                    plus_smoothie(choice)
                    continue      
                elif choice == 11:
                    plus_smoothie(choice)
                    continue 
                elif choice == 12:
                    plus_smoothie(choice)
                    continue       
                elif choice == 13:
                    plus_smoothie(choice)
                    continue 
                elif choice == 14:
                    plus_smoothie(choice)
                    continue
                elif choice == 15:
                    plus_smoothie(choice)
                    continue
                elif choice == 16:
                    plus_smoothie(choice)
                    continue
                elif choice == 17:
                    plus_smoothie(choice)
                    continue
                elif choice == 18: 
                    break

        elif menu_choice == 7:   # 커피
            for f in range(len(coffee)):
                print(f + 1, '.', coffee[f], '-', coffee_price[f])
            print('7 . 뒤로가기')
            while True:
                choice = int(input('커피 -> 숫자를 입력하세요: '))
                if choice == 1:   # 돌체카페라떼
                    for ff in range(len(size)):
                        print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 2:
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 2:   # 카라멜카페라떼
                    plus_coffee(choice)
                    # for ff in range(len(size)):
                    #     print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
                    # print('3 . 뒤로가기')  
                    # while True:
                    #     choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                    #     if choice == 1:   # 사이즈
                    #         order.append(coffee[choice-1])
                    #         total += coffee_price[choice-1]  
                    #         size_coffee(choice)
                    #         break
                    #     elif choice == 2:
                    #         order.append(coffee[choice-1])
                    #         total += coffee_price[choice-1]  
                    #         size_coffee(choice)
                    #         break
                    #     elif choice == 3:
                    #         break
                    #     # break
                    continue

                elif choice == 3:   # 바닐라카페라떼
                    for ff in range(len(size)):
                        print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 2:
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 4:   # 모카카페라떼
                    for ff in range(len(size)):
                        print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 2:
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue
                
                # elif choice == 5:
                #     plus_coffee(choice)
                #     continue

                elif choice == 5:   # 아메리카노
                    for ff in range(len(size)):
                        print(ff + 1, '.', size[ff], '-', americano_size_price[ff])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_americano(choice)
                            break
                        elif choice == 2:
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_americano(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue

                elif choice == 6:   # 카페라떼
                    for ff in range(len(size)):
                        print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
                    print('3 . 뒤로가기')  
                    while True:
                        choice = int(input('사이즈 -> 숫자를 입력하세요: '))
                        if choice == 1:   # 사이즈
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 2:
                            order.append(coffee[choice-1])
                            total += coffee_price[choice-1]  
                            size_coffee(choice)
                            break
                        elif choice == 3:
                            break
                        break
                    continue         

                elif choice == 7:
                    break

            else:
                break   # 이거 왜 색이 연하지
        else:
            break
        break
    print(order)
    print('총 ', total, '원입니다.')

def main():
    # first_display(menu)
    choice_drink(menu)
    pay(current_pay)
    receipt(current_pay)
    
if __name__ == '__main__':
    main()
# Out:
# 환영합니다. 공차입니다.
# 메뉴를 골라주세요.
#
# 1 . 베스트콤비네이션
# 2 . 오리지널 티
# 3 . 밀크티
# 4 . 브라운 슈가
# 5 . 과일믹스
# 6 . 스무디
# 7 . 커피
# 메뉴 -> 숫자를 입력하세요: 1
# 1 . 블랙밀크티+펄 - 4200
# 2 . 타로밀크티+펄 - 4200
# 3 . 망고요구르트+화이트펄 - 5200
# 4 . 제주그린밀크티+펄 - 4900
# 5 . 패션후르츠히비스커스+코코넛 - 4500
# 6 . 우롱티+밀크폼 - 3700
# 7 . 뒤로가기
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ...
