# %% [markdown]
# <a href="https://colab.research.google.com/github/Chominseo99/python_projects/blob/main/gongcha3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 포스기, 키오스크 만들기
# 메뉴, 음료 선택, 사이즈, 타입(아이스, 핫), 토핑, 당도, 얼음양

import datetime
from typing import MutableSequence

menu = ['best_combination', 'original_tea', 'milk_tea', 'brown_sugar', 'fruit_mix', 'smoothie', 'coffee']
# menu_name = ''
# menu_dict[menu_name][0]['drink']

menu_dict = {
    'best_combination':  [
        {'drink':'블랙밀크티+펄', 'price':4200, 'size_up':1200, },
        {'drink':'타로밀크티+펄', 'price':4200, 'size_up':1200, },
        {'drink':'망고요구르트+화이트펄', 'price':5200, 'size_up':1200, },
        {'drink':'제주그린밀크티+펄', 'price':4900, 'size_up':1200, },
        {'drink':'패션후르츠히비스커스+코코넛', 'price':4500, 'size_up':1200, },
        {'drink':'우롱티+밀크폼', 'price':3700, 'size_up':1200, }
    ],  
    'original_tea': [
        {'drink':'자스민그린티', 'price':3500, 'size_up':1100, },
        {'drink':'우롱티', 'price':3500, 'size_up':1100, },
        {'drink':'블랙티', 'price':3500, 'size_up':1100, },
        {'drink':'얼그레이티', 'price':3500, 'size_up':1100, }
    ],
    'milk_tea': [
        {'drink':'민트초코칩밀크티+펄', 'price':4900, 'size_up':0, },
        {'drink':'복숭아쥬얼리밀크티', 'price':5100, 'size_up':0, },
        {'drink':'피스타치오밀크티+펄', 'price':4900, 'size_up':0, },
        {'drink':'망고치즈폼밀크티', 'price':4900, 'size_up':0, },
        {'drink':'딸기쥬얼리밀크티', 'price':5100, 'size_up':0, },
        {'drink':'자스민그린밀크티', 'price':4000, 'size_up':1100, },
        {'drink':'우롱밀크티', 'price':4000, 'size_up':1100, },
        {'drink':'블랙밀크티', 'price':4000, 'size_up':1100, },
        {'drink':'얼그레이밀크티', 'price':4000, 'size_up':1100, },
        {'drink':'타로밀크티', 'price':4000, 'size_up':1100, },
        {'drink':'초콜렛밀크티', 'price':4000, 'size_up':1100, },
        {'drink':'제주그린밀크티', 'price':4700, 'size_up':1100, },
        {'drink':'딸기쏙쏙쥬얼리밀크티', 'price':5100, 'size_up':0, },
        {'drink':'딸기쿠키밀크티', 'price':4900, 'size_up':0, }
    ], 
    'brown_sugar': [
        {'drink':'브라운슈가치즈폼쿠키밀크티', 'price':5700, 'size_up':0, },
        {'drink':'브라운슈가커피밀크티', 'price':5700, 'size_up':0, },
        {'drink':'브라운슈가쥬얼리밀크티', 'price':5300, 'size_up':0, },
        {'drink':'브라운슈가치즈폼스무디', 'price':5700, 'size_up':0, }
    ],
    'fruit_mix': [
        {'drink':'망고쥬스', 'price':4600, 'size_up':1100, },
        {'drink':'망고요구르트', 'price':5000, 'size_up':1100, },
        {'drink':'자몽그린티', 'price':4300, 'size_up':1100, },
        {'drink':'청포도그린티', 'price':4300, 'size_up':1100, },                
        {'drink':'패션후르츠히비스커스', 'price':4300, 'size_up':1100, },
        {'drink':'자몽주스', 'price':4600, 'size_up':1100, }
    ],
    'smoothie': [
        {'drink':'민트팝핑초코스무디', 'price':5300, 'size_up':0, },
        {'drink':'초코바른민트쿠키스무디', 'price':5300, 'size_up':0, },
        {'drink':'복숭아쥬얼리요구르트크러쉬', 'price':5300, 'size_up':0, },
        {'drink':'초코바른피스타치오스무디', 'price':5300, 'size_up':0, },
        {'drink':'망고요구르트쥬얼리크러쉬', 'price':5300, 'size_up':0, },
        {'drink':'돌체크러쉬위드샷L', 'price':5300, 'size_up':0, },
        {'drink':'초코바른제주그린스무디', 'price':5700, 'size_up':0, },
        {'drink':'초코바른초코스무디', 'price':5500, 'size_up':0, },
        {'drink':'딸기&요구르트크러쉬', 'price':5300, 'size_up':0, },
        {'drink':'치즈폼딥초코스무디', 'price':5300, 'size_up':0, },
        {'drink':'망고스무디L', 'price':5300, 'size_up':0, },
        {'drink':'초코쿠앤크스무디L', 'price':4500, 'size_up':0, },
        {'drink':'청포도스무디L', 'price':4800, 'size_up':0, },
        {'drink':'제주그린티스무디L', 'price':5300, 'size_up':0, },
        {'drink':'체리바른딸기크러쉬', 'price':5500, 'size_up':0, },
        {'drink':'딸기치즈쿠키크러쉬', 'price':5500, 'size_up':0, },
        {'drink':'딸기쿠키스무디', 'price':5300, 'size_up':0, }
    ],
    'coffee': [
        {'drink':'돌체카페라떼', 'price':4700, 'size_up':1100, },
        {'drink':'카라멜카페라떼', 'price':4500, 'size_up':1100, },
        {'drink':'바닐라카페라떼', 'price':4500, 'size_up':1100, },
        {'drink':'모카카페라떼', 'price':4500, 'size_up':1100, },
        {'drink':'아메리카노', 'price':3500, 'size_up':500, },
        {'drink':'카페라떼', 'price':4000, 'size_up':1100, }
    ]

}


# size = [{'라지':0}, {'점보':0}]
size = ['L', 'J']

# type = [{'ICE':0}, {'HOT':0}]
type = ['ICE', 'HOT']

# sugar = [{'0%':0, '30%':0, '50%':0, '70%':0, '100%':0}]
sugar = ['0%', '30%', '50%', '70%', '100%']
# sugar_price = 0

# ice = [{'Less':0, 'Regular':0, 'Full':0}]
ice = ['Less', 'Regular', 'Full']
# ice_price = 0

# topping = [{'밀크폼':700, '펄':700, '코코넛':700, '알로에':700, '화이트펄':700}]
topping = [
    {'name':'밀크폼', 'price':700, 'size_up':700},
    {'name':'펄', 'price':700, 'size_up':700},
    {'name':'코코넛', 'price':700, 'size_up':700},
    {'name':'알로에', 'price':700, 'size_up':700},
    {'name':'화이트펄', 'price':700, 'size_up':700}
]
# topping_price = 700

# # no_choice_sugar = [{'당도고정':0}]
# no_choice_sugar = ['당도고정']
# # no_choice_sugar_price = 0

# # no_choice_ice = [{'얼음양 고정':0}]
# no_choice_ice = ['얼음양 고정']
# # no_choice_ice_price = 0

current_pay = 0 


# def choice_drink(my_choice_drink):
#     global total
#     while True:
#         print('환영합니다. 공차입니다.\n메뉴를 골라주세요.\n')
#         for main in range(len(menu)):
#             print(main + 1, '.' , menu[main])
#         my_choice_menu = int(input('메뉴 -> 숫자를 입력하세요: '))
#         if my_choice_menu == 1:   # 베스트콤비네이션
#             # 베스트콤비네이션 메뉴 출력
#             for best_combination_menu in menu_dict['best_combination']:
#                 print('{0} - {1}원'.format(best_combination_menu['drink'],best_combination_menu['price']))
#                 # 마지막에 (끝나는 숫자 . 뒤로가기) 출력 ---> 어떻게............
#         # while True:
#             my_choice_drink = int(input('음료 -> 숫자를 입력하세요: '))
#             if my_choice_drink == 1:   # 블랙밀크티+펄
#                 for my_best_combination_drink in menu_dict['best_combination']:
#                     print(my_best_combination_drink['drink'])
#                     # break
#                 break
#             break
#         break
        

# def selected_drink(category_choice, menu_choice):
#     my_category = menu[category_choice-1]
#     order.append(menu_dict[my_category][menu_choice-1]['drink'])
#     total = menu_dict[my_category][menu_choice-1]['price']
#     return total

# def selected_size(category_choice, size_choice):
#     global total
#     order.append(menu_dict[category_choice-1][size_choice-1]['size_up'])
#     total += menu_dict[category_choice-1][size_choice-1]['size_up']
#     return total

# def selected_topping(topping_choice):
#     global total
#     global order
#     order.append(topping[topping_choice-1]['name'])
#     total += topping[topping_choice-1]['price']
#     return (order, total) 


# def pay(pay_input):
#     global current_pay

#     while True:
#         pay_input = int(input('넣을 금액을 입력하세요: '))
#         current_pay += pay_input 

#         if current_pay < total:
#             print('현재 현금 ', current_pay, '원')
#             print('금액이 부족합니다. 더 넣어주세요.')
#         elif current_pay >= total:
#             print('잔돈 ', current_pay - total, '원')
#             break
    
# def all_order(*order):
#     for total_all_order in order:
#          print("%s %s" % total_all_order[0], total_all_order[1], end='')
#     print("\n")

def receipt(order):
    # global current_pay
    # global order
    while True:

        now = datetime.datetime.now()
        nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S') 

        receipt_paper = '''
            공차 성수점
            대표: 조민서
            주소: 서울시 떡잎구 초록동
            전번: 0102-22933-1

            오늘도 공차를 찾아주셔서 감사합니다.
            '''
        print(receipt_paper)
        print('-------------------------------------------------')
        print('       메뉴                             금액       ')
        print('{0} {1}  {2}추가           {3}'.format(order['beverage'], order['size'], order['topping'], order['total_price']))

        # for my_order in order:
        #     print('{0} {1} {2}'.format(order['beverage'], order['size'], order['topping']))
        print(sep='\n')
        # print(*order, sep='\n')       
        # print(type(order['total_price']))
        print('-------------------------------------------------')
        # my_total_price = order['total_price']
        # print(my_total_price)
        print('합계 {0}원'.format(order['total_price']))
        # print('합계 ', total, '원')
        # print('현금 ', current_pay, '원')
        # print('잔돈 ', current_pay - total, '원')
        print('판매일 ', nowDatetime)
        break


def print_categories(menu):
    print('환영합니다. 공차입니다.\n카테고리를 골라주세요.\n')
    for idx, el in enumerate(menu): 
        print(idx + 1, '.', el) 


# order = {}
def order_drink(menu):
    # global order
    order = {}
    while True:
        category_choice = int(input('카테고리 -> 숫자를 입력하세요: '))
        if category_choice == 0 or category_choice > len(menu) :
            print('다른 숫자를 입력해주세요.')
            continue
        else:
            break


    my_category = menu[category_choice-1]   # 'best_combination'
    for idx, el in enumerate(menu_dict[my_category]):
        print(idx + 1, '.', el['drink'], '-', el['price'])
    print(len(menu_dict[my_category]) + 1, '.', '뒤로가기')
    while True:
        menu_choice = int(input('음료 -> 숫자를 입력하세요: '))
        if menu_choice == 0 or menu_choice > len(menu_dict[my_category]):
            print('다른 숫자를 입력해주세요.')
            continue
        else:
            break
    my_menu = menu_dict[my_category][menu_choice-1]  # {'drink':'블랙밀크티+펄', 'price':4200, 'size_up':1200, }
    order['beverage'] = my_menu['drink']   # 음료이름 저장
    print(order)

    # 사이즈 고르기
    for idx, el in enumerate(size):   # 'L', 'J'
        print(idx + 1, '.', el)
    print(len(size) + 1, '.', '뒤로가기')
    while True:
        size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))   # 1 or 2 or 3
        if size_choice== 0 or size_choice > len(size):
            print('다른 숫자를 입력해주세요.')
            continue
        else:
            break

    order['size'] = size[size_choice-1]   # 사이즈 저장
    print(order)
    total = my_menu['price'] 
    if size_choice == 2:
        total += my_menu['size_up']

    # 토핑 고르기
    if size_choice == 1:
        for idx, el in enumerate(topping):
            print(idx + 1, '.', el['name'], '-', el['price'])
        print(len(topping) + 1, '.', '뒤로가기')
        while True:
            topping_choice = int(input('토핑 -> 숫자를 입력하세요: '))
            if topping_choice== 0 or topping_choice > len(topping):
                print('다른 숫자를 입력해주세요.')
                continue
            else:
                break
        total += topping[topping_choice-1]['price']

    elif size_choice == 2:
        for idx, el in enumerate(topping):
            print(idx + 1, '.', el['name'], '-', el['price'] + el['size_up'])
        print(len(topping) + 1, '.', '뒤로가기')
        while True:
            topping_choice = int(input('토핑 -> 숫자를 입력하세요: '))
            if topping_choice == 0 or topping_choice > len(topping):
                print('다른 숫자를 입력해주세요.')
                continue
            else:
                break
        total += topping[topping_choice-1]['price'] 
        total += topping[topping_choice-1]['size_up']   
    
    
    order['total_price'] = total   # total 저장
    order['topping'] = topping[topping_choice-1]['name']   # 토핑 저장
    print(order)

    # print(order)  # total을 여기에 있으면 return 안해도 됨
    print('총 ', total, '원입니다.')

    return order

# def re_choice(number):
#     while True:
#         if number-1 < 10:
#             print('숫자를 다시 입력해주세요.')
#             break
#         else:
#             continue

# def end(self, quit):
#     while True:
#         if quit == 'q':
#             print('종료합니다.')
#             break
#         else:
#             continue

# 쪼개지말고 일단 성공해
# total, order 똑바로 나오기 


def main():
    print_categories(menu)
    # ccchoice_drink(menu)
    # pay(current_pay)
    # receipt(current_pay)
    # choice_drink(my_choice_drink)
    order = order_drink(menu)

    # pay(current_pay)
    
    receipt(order)

if __name__ == '__main__':
    main()
# Out:
# 환영합니다. 공차입니다.
# 카테고리를 골라주세요.
#
# 1 . best_combination
# 2 . original_tea
# 3 . milk_tea
# 4 . brown_sugar
# 5 . fruit_mix
# 6 . smoothie
# 7 . coffee
# 카테고리 -> 숫자를 입력하세요: 3
# 1 . 민트초코칩밀크티+펄 - 4900
# 2 . 복숭아쥬얼리밀크티 - 5100
# 3 . 피스타치오밀크티+펄 - 4900
# 4 . 망고치즈폼밀크티 - 4900
# 5 . 딸기쥬얼리밀크티 - 5100
# 6 . 자스민그린밀크티 - 4000
# 7 . 우롱밀크티 - 4000
# 8 . 블랙밀크티 - 4000
# 9 . 얼그레이밀크티 - 4000
# 10 . 타로밀크티 - 4000
# 11 . 초콜렛밀크티 - 4000
# 12 . 제주그린밀크티 - 4700
# 13 . 딸기쏙쏙쥬얼리밀크티 - 5100
# 14 . 딸기쿠키밀크티 - 4900
# 15 . 뒤로가기
# 음료 -> 숫자를 입력하세요: 2
# {'beverage': '복숭아쥬얼리밀크티'}
# 1 . L
# 2 . J
# 3 . 뒤로가기
# 사이즈 -> 숫자를 입력하세요: 1
# {'beverage': '복숭아쥬얼리밀크티', 'size': 'L'}
# 1 . 밀크폼 - 700
# 2 . 펄 - 700
# 3 . 코코넛 - 700
# 4 . 알로에 - 700
# 5 . 화이트펄 - 700
# 6 . 뒤로가기
# 토핑 -> 숫자를 입력하세요: 3
# {'beverage': '복숭아쥬얼리밀크티', 'size': 'L', 'total_price': 5800, 'topping': '코코넛'}
# 총  5800 원입니다.
#
#             공차 성수점
#             대표: 조민서
#             주소: 서울시 떡잎구 초록동
#             전번: 0102-22933-1
#
#             오늘도 공차를 찾아주셔서 감사합니다.
#
# ...

# %%
# def re_choice(number):
#     while True:
#         if number-1 < 10:
#             print('숫자를 다시 입력해주세요.')
#             break
#         else:
#             continue

# def end(self, quit):
#     while True:
#         if quit == 'q':
#             print('종료합니다.')
#             break
#         else:
#             continue

# 쪼개지말고 일단 성공해
# total, order 똑바로 나오기 


def main():
    print_categories(menu)
    # ccchoice_drink(menu)
    # pay(current_pay)
    # receipt(current_pay)
    # choice_drink(my_choice_drink)
    order = order_drink(menu)

    # pay(current_pay)
    
    receipt(order)

if __name__ == '__main__':
    main()



    # print(order)
    # print('총 ', total, '원입니다.')


        #     if menu_choice == 1:   # 블랙밀크티+펄
        #         for aa in range(len(size)):
        #             print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
        #         print('3 . 뒤로가기')
        #         while True:
        #             size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             # --> 사용자가 입력한 사이즈에 대해 이 내용을 실행한다.
        #             # 이 내용을 실행한다(사용자가 입력한 사이즈)
        #             # do_sth(size)
        #             # 사용자가 사이즈를 입력한다
        #             if size_choice == 1 :   # 사이즈
        #                 # 사용자가 입력한 사이즈가 1이면
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 # 이 내용을 실행한다
        #                 break
        #             elif size_choice == 2:
        #                 # 사용자가 입력한 사이즈가 2이면
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 # 이 내용(같음)을 실행한다
        #                 break
        #             elif size_choice == 3:
        #                 # first_display(menu)
        #                 # print(main)
        #                 # continue
        #                 break   # !!!
        #             break   # ...? 이건 의미 없? 
        #         continue

        #     elif best_combination_choice == 2:   # 타로밀크티+펄
        #         for aa in range(len(size)):
        #             print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
        #         print('3 . 뒤로가기')    
        #         while True:
        #             size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             if size_choice == 1:   # 사이즈
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 2:
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 3:
        #                 break
        #             break
        #         continue

        #     elif best_combination_choice == 3:   # 망고요구르트+화이트펄
        #         print(menu_dict['best_combination'][best_combination_choice-1])
        #         # plus_best_combination(choice) 
        #         for aa in range(len(size)):
        #             print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
        #         print('3 . 뒤로가기')    
        #         while True:
        #             size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             if size_choice == 1:   # 사이즈
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 print(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 2:
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 3:
        #                 break
        #         continue

        #     elif best_combination_choice == 4:   # 제주그린밀크티+펄
        #         # plus_best_combination(choice) 
        #         for aa in range(len(size)):
        #             print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
        #         print('3 . 뒤로가기')    
        #         while True:
        #             size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             if size_choice == 1:   # 사이즈
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 2:
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 3:
        #                 break
        #         continue

        #     elif best_combination_choice == 5:   # 패션후르츠히비스커스+코코넛
        #         # plus_best_combination(choice) 
        #         for aa in range(len(size)):
        #             print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
        #         print('3 . 뒤로가기')    
        #         while True:
        #             size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             if size_choice == 1:   # 사이즈
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 2:
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 3:
        #                 break
        #         continue

        #     elif best_combination_choice == 6:   # 우롱티+밀크폼
        #         # plus_best_combination(choice) 
        #         for aa in range(len(size)):
        #             print(aa + 1, '.', size[aa], '-', best_combination_size_price[aa])
        #         print('3 . 뒤로가기')    
        #         while True:
        #             size_choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             if size_choice == 1:   # 사이즈
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 2:
        #                 order.append(menu_dict['best_combination'][best_combination_choice-1])
        #                 total += best_combination_price[best_combination_choice-1]
        #                 size_best_combination(size_choice)
        #                 break
        #             elif size_choice == 3:
        #                 break
        #         continue

        #     elif best_combination_choice == 7:
        #         break

        # elif menu_choice == 2:   # 오리지널티
        #     for b in range(len(menu_dict['original_tea'])):
        #         print(b + 1, '.', menu_dict['original_tea'][b], '-', original_tea_price[b])
        #     print('5 . 뒤로가기')
        #     while True:
        #         choice = int(input('오리지널 티 -> 숫자를 입력하세요: '))
        #         if choice == 1:   # 자스민그린티
        #             for bb in range(len(size)):
        #                 print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 2:   # 우롱티
        #             for bb in range(len(size)):
        #                 print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue      

        #         elif choice == 3:   # 블랙티
        #             for bb in range(len(size)):
        #                 print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 4:   # 얼그레이티
        #             for bb in range(len(size)):
        #                 print(bb + 1, '.', size[bb], '-', original_tea_size_price[bb])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['original_tea'][choice-1])
        #                     total += original_tea_price[choice-1]  
        #                     size_original_tea(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 5:
        #             break

        # elif menu_choice == 3:   # 밀크티          
        #     for c in range(len(menu_dict['milk_tea'])):
        #         print(c + 1, '.', menu_dict['milk_tea'][c], '-', milk_tea_price[c])
        #     print('15 . 뒤로가기')
        #     while True:
        #         choice = int(input('숫자를 입력하세요: '))
        #         if choice == 1:
        #             plus_milk_tea(choice)
        #             continue
        #         elif choice == 2:
        #             plus_milk_tea(choice)
        #             continue      
        #         elif choice == 3:
        #             plus_milk_tea(choice)
        #             continue 
        #         elif choice == 4:
        #             plus_milk_tea(choice)
        #             continue  
        #         elif choice == 5:
        #             plus_milk_tea(choice)
        #             continue      
        #         elif choice == 6:
        #             plus_milk_tea(choice)
        #             continue 
        #         elif choice == 7:
        #             plus_milk_tea(choice)
        #             continue
        #         elif choice == 8:
        #             plus_milk_tea(choice)
        #             continue 
        #         elif choice == 9:
        #             plus_milk_tea(choice)
        #             continue  
        #         elif choice == 10:
        #             plus_milk_tea(choice)
        #             continue      
        #         elif choice == 11:
        #             plus_milk_tea(choice)
        #             continue 
        #         elif choice == 12:
        #             plus_milk_tea(choice)
        #             continue       
        #         elif choice == 13:
        #             plus_milk_tea(choice)
        #             continue 
        #         elif choice == 14:
        #             plus_milk_tea(choice)
        #             continue
        #         elif choice == 15: 
        #             break

        # elif menu_choice == 4:                
        #     for d in range(len(menu_dict['brown_sugar'])):
        #         print(d + 1, '.', menu_dict['brown_sugar'][d], '-', brown_sugar_price[d])
        #     print('5 . 뒤로가기')
        #     while True:
        #         choice = int(input('숫자를 입력하세요: '))
        #         if choice == 1:
        #             plus_brown_sugar(choice)
        #             continue
        #         elif choice == 2:
        #             plus_brown_sugar(choice)
        #             continue      
        #         elif choice == 3:
        #             plus_brown_sugar(choice)
        #             continue 
        #         elif choice == 4:
        #             plus_brown_sugar(choice)
        #             continue  
        #         elif choice == 5:
        #             break

        # elif menu_choice == 5:   # 과일믹스
        #     for e in range(len(menu_dict['fruit_mix'])):
        #         print(e + 1, '.', menu_dict['fruit_mix'][e], '-', fruit_mix_price[e])
        #     print('7 . 뒤로가기')
        #     while True:
        #         choice = int(input('과일믹스 -> 숫자를 입력하세요: '))
        #         if choice == 1:   # 망고쥬스
        #             # plus_fruit_mix(choice)
        #             for ee in range(len(size)):
        #                 print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
        #             print('3 . 뒤로가기')
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 2:   # 망고요구르트
        #             for ee in range(len(size)):
        #                 print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
        #             print('3 . 뒤로가기')
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 3:   # 자몽그린티
        #             for ee in range(len(size)):
        #                 print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
        #             print('3 . 뒤로가기')
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 4:   # 청포도그린티
        #             for ee in range(len(size)):
        #                 print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
        #             print('3 . 뒤로가기')
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 5:   # 패션후르츠히비스커스
        #             for ee in range(len(size)):
        #                 print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
        #             print('3 . 뒤로가기')
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 6:   # 자몽주스
        #             for ee in range(len(size)):
        #                 print(ee + 1, '.', size(ee), '-', fruit_mix_size_price(ee))
        #             print('3 . 뒤로가기')
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['fruit_mix'][choice-1])
        #                     total += fruit_mix_price[choice-1]
        #                     size_fruit_mix(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue       

        #         elif choice == 7:
        #             break

        # elif menu_choice == 6:                
        #     for f in range(len(menu_dict['smoothie'])):
        #         print(f + 1, '.', menu_dict['smoothie'][f], '-', smoothie_price[f])
        #     print('18 . 뒤로가기')
        #     while True:
        #         choice = int(input('숫자를 입력하세요: '))
        #         if choice == 1:
        #             plus_smoothie(choice)
        #             continue
        #         elif choice == 2:
        #             plus_smoothie(choice)
        #             continue      
        #         elif choice == 3:
        #             plus_smoothie(choice)
        #             continue 
        #         elif choice == 4:
        #             plus_smoothie(choice)
        #             continue  
        #         elif choice == 5:
        #             plus_smoothie(choice)
        #             continue      
        #         elif choice == 6:
        #             plus_smoothie(choice)
        #             continue 
        #         elif choice == 7:
        #             plus_smoothie(choice)
        #             continue
        #         elif choice == 8:
        #             plus_smoothie(choice)
        #             continue 
        #         elif choice == 9:
        #             plus_smoothie(choice)
        #             continue  
        #         elif choice == 10:
        #             plus_smoothie(choice)
        #             continue      
        #         elif choice == 11:
        #             plus_smoothie(choice)
        #             continue 
        #         elif choice == 12:
        #             plus_smoothie(choice)
        #             continue       
        #         elif choice == 13:
        #             plus_smoothie(choice)
        #             continue 
        #         elif choice == 14:
        #             plus_smoothie(choice)
        #             continue
        #         elif choice == 15:
        #             plus_smoothie(choice)
        #             continue
        #         elif choice == 16:
        #             plus_smoothie(choice)
        #             continue
        #         elif choice == 17:
        #             plus_smoothie(choice)
        #             continue
        #         elif choice == 18: 
        #             break

        # elif menu_choice == 7:   # 커피
        #     for f in range(len(menu_dict['coffee'])):
        #         print(f + 1, '.', menu_dict['coffee'][f], '-', coffee_price[f])
        #     print('7 . 뒤로가기')
        #     while True:
        #         choice = int(input('커피 -> 숫자를 입력하세요: '))
        #         if choice == 1:   # 돌체카페라떼
        #             for ff in range(len(size)):
        #                 print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 2:   # 카라멜카페라떼
        #             plus_coffee(choice)
        #             # for ff in range(len(size)):
        #             #     print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
        #             # print('3 . 뒤로가기')  
        #             # while True:
        #             #     choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #             #     if choice == 1:   # 사이즈
        #             #         order.append(coffee[choice-1])
        #             #         total += coffee_price[choice-1]  
        #             #         size_coffee(choice)
        #             #         break
        #             #     elif choice == 2:
        #             #         order.append(coffee[choice-1])
        #             #         total += coffee_price[choice-1]  
        #             #         size_coffee(choice)
        #             #         break
        #             #     elif choice == 3:
        #             #         break
        #             #     # break
        #             continue

        #         elif choice == 3:   # 바닐라카페라떼
        #             for ff in range(len(size)):
        #                 print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 4:   # 모카카페라떼
        #             for ff in range(len(size)):
        #                 print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue
                
        #         # elif choice == 5:
        #         #     plus_coffee(choice)
        #         #     continue

        #         elif choice == 5:   # 아메리카노
        #             for ff in range(len(size)):
        #                 print(ff + 1, '.', size[ff], '-', americano_size_price[ff])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_americano(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_americano(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue

        #         elif choice == 6:   # 카페라떼
        #             for ff in range(len(size)):
        #                 print(ff + 1, '.', size[ff], '-', coffee_size_price[ff])
        #             print('3 . 뒤로가기')  
        #             while True:
        #                 choice = int(input('사이즈 -> 숫자를 입력하세요: '))
        #                 if choice == 1:   # 사이즈
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 2:
        #                     order.append(menu_dict['coffee'][choice-1])
        #                     total += coffee_price[choice-1]  
        #                     size_coffee(choice)
        #                     break
        #                 elif choice == 3:
        #                     break
        #                 break
        #             continue         

        #         elif choice == 7:
        #             break

        #     else:
        #         break   # 이거 왜 색이 연하지
        # else:
        #     break
        # break
    # print(order)
    # print('총 ', total, '원입니다.')
